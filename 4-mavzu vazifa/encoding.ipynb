# %% [markdown]
# Encoding

# %%
import pandas as pd

# %%
df=pd.read_csv('4-mavzu vazifa/placementdata_with_faculty.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df=pd.read_csv('4-mavzu vazifa/placementdata_with_faculty.csv')
#
# File c:\Users\Abdulmuxtor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Abdulmuxtor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Abdulmuxtor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Abdulmuxtor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Abdulmuxtor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '4-mavzu vazifa/placementdata_with_faculty.csv'

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                    65               4.4                        No
# 1                    90               4.0                       Yes
# 2                    82               4.8                       Yes
# 3                    85               4.4                       Yes
# 4                    86               4.5                       Yes
# ...                 ...               ...                       ...
# 9995                 72               3.9                       Yes
# 9996                 90               4.8                        No
# 9997                 70               4.8                       Yes
# 9998                 87               4.8                       Yes
# 9999                 66               3.8                        No
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus  \
# 0                   No         61         79       NotPlaced
# 1                  Yes         78         82          Placed
# 2                   No         79         80       NotPlaced
# 3                  Yes         81         80          Placed
# 4                  Yes         74         88          Placed
# ...                ...        ...        ...             ...
# 9995                No         85         66       NotPlaced
# 9996                No         84         67          Placed
# 9997               Yes         79         81          Placed
# 9998               Yes         71         85          Placed
# 9999                No         62         66       NotPlaced
#
#                       faculty
# 0     Business Administration
# 1            Computer Science
# 2            Computer Science
# 3           Civil Engineering
# 4      Electrical Engineering
# ...                       ...
# 9995         Computer Science
# 9996   Electrical Engineering
# 9997            Biotechnology
# 9998         Computer Science
# 9999         Computer Science
#
# [10000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# faculty                      0
# dtype: int64

# %%
df['faculty'].value_counts()
# Out:
# faculty
# Computer Science           4020
# Business Administration    1511
# Mechanical Engineering     1484
# Civil Engineering          1013
# Electrical Engineering      999
# Biotechnology               973
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
#  12  faculty                    10000 non-null  object
# dtypes: float64(2), int64(7), object(4)
# memory usage: 1015.8+ KB

# %%
df.PlacementTraining.value_counts()
# Out:
# PlacementTraining
# Yes    7318
# No     2682
# Name: count, dtype: int64

# %%
df.faculty.value_counts()
# Out:
# faculty
# Computer Science           4020
# Business Administration    1511
# Mechanical Engineering     1484
# Civil Engineering          1013
# Electrical Engineering      999
# Biotechnology               973
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
#  12  faculty                    10000 non-null  object
# dtypes: float64(2), int64(7), object(4)
# memory usage: 1015.8+ KB

# %% [markdown]
# #one-hot encoder

# %%
df=pd.get_dummies(df,columns=['faculty'],dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   StudentID                        10000 non-null  int64
#  1   CGPA                             10000 non-null  float64
#  2   Internships                      10000 non-null  int64
#  3   Projects                         10000 non-null  int64
#  4   Workshops/Certifications         10000 non-null  int64
#  5   AptitudeTestScore                10000 non-null  int64
#  6   SoftSkillsRating                 10000 non-null  float64
#  7   ExtracurricularActivities        10000 non-null  object
#  8   PlacementTraining                10000 non-null  object
#  9   SSC_Marks                        10000 non-null  int64
#  10  HSC_Marks                        10000 non-null  int64
#  11  PlacementStatus                  10000 non-null  object
#  12  faculty_Biotechnology            10000 non-null  int64
#  13  faculty_Business Administration  10000 non-null  int64
#  14  faculty_Civil Engineering        10000 non-null  int64
#  15  faculty_Computer Science         10000 non-null  int64
#  16  faculty_Electrical Engineering   10000 non-null  int64
#  17  faculty_Mechanical Engineering   10000 non-null  int64
# dtypes: float64(2), int64(13), object(3)
# memory usage: 1.4+ MB

# %%
df['faculty_Biotechnology'].value_counts()
# Out:
# faculty_Biotechnology
# 0    9027
# 1     973
# Name: count, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['StudentID',
#  'CGPA',
#  'Internships',
#  'Projects',
#  'Workshops/Certifications',
#  'AptitudeTestScore',
#  'SoftSkillsRating',
#  'ExtracurricularActivities',
#  'PlacementTraining',
#  'SSC_Marks',
#  'HSC_Marks',
#  'PlacementStatus',
#  'faculty_Biotechnology',
#  'faculty_Business Administration',
#  'faculty_Civil Engineering',
#  'faculty_Computer Science',
#  'faculty_Electrical Engineering',
#  'faculty_Mechanical Engineering']

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# faculty                      0
# dtype: int64

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\abdulmuxtor\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\abdulmuxtor\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.1 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.1 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.1 MB 2.3 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.1 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.1 MB 2.2 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.1 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/11.1 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.5/11.1 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.0/11.1 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.1 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.1 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.6/11.1 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/11.1 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.1 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.1/11.1 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/11.1 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/11.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 2.3 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df['faculty']=encoder.fit_transform(df['faculty'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
#  12  faculty                    10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                    65               4.4                        No
# 1                    90               4.0                       Yes
# 2                    82               4.8                       Yes
# 3                    85               4.4                       Yes
# 4                    86               4.5                       Yes
# ...                 ...               ...                       ...
# 9995                 72               3.9                       Yes
# 9996                 90               4.8                        No
# 9997                 70               4.8                       Yes
# 9998                 87               4.8                       Yes
# 9999                 66               3.8                        No
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus  \
# 0                   No         61         79       NotPlaced
# 1                  Yes         78         82          Placed
# 2                   No         79         80       NotPlaced
# 3                  Yes         81         80          Placed
# 4                  Yes         74         88          Placed
# ...                ...        ...        ...             ...
# 9995                No         85         66       NotPlaced
# 9996                No         84         67          Placed
# 9997               Yes         79         81          Placed
# 9998               Yes         71         85          Placed
# 9999                No         62         66       NotPlaced
#
#                       faculty
# 0     Business Administration
# 1            Computer Science
# 2            Computer Science
# 3           Civil Engineering
# 4      Electrical Engineering
# ...                       ...
# 9995         Computer Science
# 9996   Electrical Engineering
# 9997            Biotechnology
# 9998         Computer Science
# 9999         Computer Science
#
# [10000 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['PlacementStatus']=encoder.fit_transform(df['PlacementStatus'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  int64
#  12  faculty                    10000 non-null  object
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks  PlacementStatus  \
# 0                No         61         79                0
# 1               Yes         78         82                1
# 2                No         79         80                0
# 3               Yes         81         80                1
# 4               Yes         74         88                1
#
#                    faculty
# 0  Business Administration
# 1         Computer Science
# 2         Computer Science
# 3        Civil Engineering
# 4   Electrical Engineering

# %%
#target encoder

# %%
df['faculty_target']=df.groupby('faculty')['PlacementStatus'].transform('mean')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  int64
#  12  faculty                    10000 non-null  object
#  13  faculty_target             10000 non-null  float64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df['faculty_target']
# Out:
# 0       0.424222
# 1       0.411692
# 2       0.411692
# 3       0.429418
# 4       0.429429
#           ...
# 9995    0.411692
# 9996    0.429429
# 9997    0.428571
# 9998    0.411692
# 9999    0.411692
# Name: faculty_target, Length: 10000, dtype: float64

# %%
df.drop(columns='faculty',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  int64
#  12  faculty_target             10000 non-null  float64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1015.8+ KB

# %%
df.info()
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                    65               4.4                        No
# 1                    90               4.0                       Yes
# 2                    82               4.8                       Yes
# 3                    85               4.4                       Yes
# 4                    86               4.5                       Yes
# ...                 ...               ...                       ...
# 9995                 72               3.9                       Yes
# 9996                 90               4.8                        No
# 9997                 70               4.8                       Yes
# 9998                 87               4.8                       Yes
# 9999                 66               3.8                        No
#
#      PlacementTraining  SSC_Marks  HSC_Marks  PlacementStatus  faculty_target
# 0                   No         61         79                0        0.424222
# 1                  Yes         78         82                1        0.411692
# 2                   No         79         80                0        0.411692
# 3                  Yes         81         80                1        0.429418
# 4                  Yes         74         88                1        0.429429
# ...                ...        ...        ...              ...             ...
# 9995                No         85         66                0        0.411692
# 9996                No         84         67                1        0.429429
# 9997               Yes         79         81                1        0.428571
# 9998               Yes         71         85                1        0.411692
# 9999                No         62         66                0        0.411692
#
# [10000 rows x 13 columns]

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
