# %% [markdown]
# Encoding

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Abdulmuxtor\Downloads\placementdata_with_faculty.csv")

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# faculty                      0
# dtype: int64

# %%
df['faculty'].value_counts()
# Out:
# faculty
# Computer Science           4020
# Business Administration    1511
# Mechanical Engineering     1484
# Civil Engineering          1013
# Electrical Engineering      999
# Biotechnology               973
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
#  12  faculty                    10000 non-null  object
# ...

# %%
df.PlacementTraining.value_counts()
# Out:
# PlacementTraining
# Yes    7318
# No     2682
# Name: count, dtype: int64

# %%
df.faculty.value_counts()
# Out:
# faculty
# Computer Science           4020
# Business Administration    1511
# Mechanical Engineering     1484
# Civil Engineering          1013
# Electrical Engineering      999
# Biotechnology               973
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
#  12  faculty                    10000 non-null  object
# ...

# %% [markdown]
# #one-hot encoder

# %%
df=pd.get_dummies(df,columns=['faculty'],dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   StudentID                        10000 non-null  int64
#  1   CGPA                             10000 non-null  float64
#  2   Internships                      10000 non-null  int64
#  3   Projects                         10000 non-null  int64
#  4   Workshops/Certifications         10000 non-null  int64
#  5   AptitudeTestScore                10000 non-null  int64
#  6   SoftSkillsRating                 10000 non-null  float64
#  7   ExtracurricularActivities        10000 non-null  object
#  8   PlacementTraining                10000 non-null  object
#  9   SSC_Marks                        10000 non-null  int64
#  10  HSC_Marks                        10000 non-null  int64
#  11  PlacementStatus                  10000 non-null  object
# ...

# %%
df['faculty_Biotechnology'].value_counts()
# Out:
# faculty_Biotechnology
# 0    9027
# 1     973
# Name: count, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['StudentID',
#  'CGPA',
#  'Internships',
#  'Projects',
#  'Workshops/Certifications',
#  'AptitudeTestScore',
#  'SoftSkillsRating',
#  'ExtracurricularActivities',
#  'PlacementTraining',
#  'SSC_Marks',
#  'HSC_Marks',
#  'PlacementStatus',
#  'faculty_Biotechnology',
#  'faculty_Business Administration',
#  'faculty_Civil Engineering',
#  'faculty_Computer Science',
#  'faculty_Electrical Engineering',
#  'faculty_Mechanical Engineering']

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# faculty                      0
# dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.1 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.1 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.1 MB 2.3 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.1 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.1 MB 2.2 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.1 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/11.1 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.5/11.1 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.0/11.1 MB 2.2 MB/s eta 0:00:03
# ...

# %% [markdown]
# #label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df['faculty']=encoder.fit_transform(df['faculty'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
#  12  faculty                    10000 non-null  int64
# ...

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['PlacementStatus']=encoder.fit_transform(df['PlacementStatus'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  int64
#  12  faculty                    10000 non-null  object
# ...

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks  PlacementStatus  \
# 0                No         61         79                0
# ...

# %%
#target encoder

# %%
df['faculty_target']=df.groupby('faculty')['PlacementStatus'].transform('mean')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  int64
#  12  faculty                    10000 non-null  object
# ...

# %%
df['faculty_target']
# Out:
# 0       0.424222
# 1       0.411692
# 2       0.411692
# 3       0.429418
# 4       0.429429
#           ...
# 9995    0.411692
# 9996    0.429429
# 9997    0.428571
# 9998    0.411692
# 9999    0.411692
# Name: faculty_target, Length: 10000, dtype: float64

# %%
df.drop(columns='faculty',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  int64
#  12  faculty_target             10000 non-null  float64
# ...

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus  \
# 0                No         61         79       NotPlaced
# ...

# %%
df=pd.get_dummies(df,columns=['ExtracurricularActivities'],dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   StudentID                      10000 non-null  int64
#  1   CGPA                           10000 non-null  float64
#  2   Internships                    10000 non-null  int64
#  3   Projects                       10000 non-null  int64
#  4   Workshops/Certifications       10000 non-null  int64
#  5   AptitudeTestScore              10000 non-null  int64
#  6   SoftSkillsRating               10000 non-null  float64
#  7   PlacementTraining              10000 non-null  object
#  8   SSC_Marks                      10000 non-null  int64
#  9   HSC_Marks                      10000 non-null  int64
#  10  PlacementStatus                10000 non-null  object
#  11  faculty                        10000 non-null  object
# ...

# %%
df=pd.get_dummies(df,columns=['PlacementTraining'],dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   StudentID                      10000 non-null  int64
#  1   CGPA                           10000 non-null  float64
#  2   Internships                    10000 non-null  int64
#  3   Projects                       10000 non-null  int64
#  4   Workshops/Certifications       10000 non-null  int64
#  5   AptitudeTestScore              10000 non-null  int64
#  6   SoftSkillsRating               10000 non-null  float64
#  7   SSC_Marks                      10000 non-null  int64
#  8   HSC_Marks                      10000 non-null  int64
#  9   PlacementStatus                10000 non-null  int64
#  10  faculty                        10000 non-null  int64
#  11  ExtracurricularActivities_No   10000 non-null  int64
# ...

# %%
df.columns.to_list()
# Out:
# ['StudentID',
#  'CGPA',
#  'Internships',
#  'Projects',
#  'Workshops/Certifications',
#  'AptitudeTestScore',
#  'SoftSkillsRating',
#  'SSC_Marks',
#  'HSC_Marks',
#  'PlacementStatus',
#  'faculty',
#  'ExtracurricularActivities_No',
#  'ExtracurricularActivities_Yes',
#  'PlacementTraining_No',
#  'PlacementTraining_Yes']
